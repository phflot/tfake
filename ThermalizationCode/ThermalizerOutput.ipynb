# %%
from thermalization import thermalization_main

if __name__ == "__main__":
    import os
    fakedir = "XXX"
    input_dir = "XXXX"
    sj_folder = os.path.join(input_dir, "thermal", "Sejong Face Database", "Sejong Face Database")
    fake_folder = os.path.join(input_dir, "fake")
    thermalization_main(fake_folder, sj_folder)
# Out:
# Start Training
# ...
# DF: 0.0079, PatchDiv: 0.0018, SegReg: 0.0002.: 100%|██████████████████████████████████| 122/122 [03:30<00:00,  1.73s/it]
